# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepika-Ch19/Network-intrusion-detection/blob/main/Network_Intrusion_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Read the csv file

# %%
import pandas as pd
filepath='/content/drive/MyDrive/Midterm_53_group.csv'
df = pd.read_csv(filepath)
df.head()
# Out:
#        Time           Source  No.      Destination Protocol  Length  \
# 0  0.000000    192.167.8.166    1  192.167.255.255     NBNS      92
# 1  0.784682    192.167.8.166    2  192.167.255.255     NBNS      92
# 2  1.169060  VMware_8a:5c:e6    3        Broadcast      ARP      60
# 3  2.167949  VMware_8a:5c:e6    4        Broadcast      ARP      60
# 4  3.170095  VMware_8a:5c:e6    5        Broadcast      ARP      60
#
#                                       Info
# 0                   Name query NB WPAD<00>
# 1                   Name query NB WPAD<00>
# 2  Who has 192.167.7.175? Tell 192.167.0.1
# 3  Who has 192.167.7.175? Tell 192.167.0.1
# 4  Who has 192.167.7.175? Tell 192.167.0.1

# %%
print(df.columns.tolist())
# Out:
# ['Time', 'Source', 'No.', 'Destination', 'Protocol', 'Length', 'Info']

# %%
df = pd.get_dummies(df, columns=['Protocol'], drop_first=True)
df['is_query'] = df['Info'].str.contains('query', case=False).astype(int)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['Time', 'Length']] = scaler.fit_transform(df[['Time', 'Length']])
df = df.drop(columns=['Info'])
df.head()
# Out:
#        Time           Source  No.      Destination    Length  \
# 0  0.000000    192.167.8.166    1  192.167.255.255  0.001006
# 1  0.000624    192.167.8.166    2  192.167.255.255  0.001006
# 2  0.000930  VMware_8a:5c:e6    3        Broadcast  0.000362
# 3  0.001725  VMware_8a:5c:e6    4        Broadcast  0.000362
# 4  0.002522  VMware_8a:5c:e6    5        Broadcast  0.000362
#
#    Protocol_BROWSER  Protocol_DHCP  Protocol_DNS  Protocol_HTTP  \
# 0             False          False         False          False
# 1             False          False         False          False
# 2             False          False         False          False
# 3             False          False         False          False
# 4             False          False         False          False
#
#    Protocol_ICMP  ...  Protocol_NBNS  Protocol_OCSP  Protocol_RARP  \
# 0          False  ...           True          False          False
# 1          False  ...           True          False          False
# 2          False  ...          False          False          False
# 3          False  ...          False          False          False
# 4          False  ...          False          False          False
#
#    Protocol_SSLv2  Protocol_STUN  Protocol_TCP  Protocol_TLSv1  \
# 0           False          False         False           False
# 1           False          False         False           False
# 2           False          False         False           False
# 3           False          False         False           False
# 4           False          False         False           False
#
#    Protocol_TLSv1.2  Protocol_TLSv1.3  is_query
# 0             False             False         1
# 1             False             False         1
# 2             False             False         0
# 3             False             False         0
# 4             False             False         0
#
# [5 rows x 21 columns]

# %%
from sklearn.ensemble import IsolationForest
X = df[['Time', 'Length']]
model = IsolationForest(n_estimators=100, contamination=0.05, random_state=42)
df['anomaly'] = model.fit_predict(X)
print(df['anomaly'].value_counts())
df[df['anomaly'] == -1].head()
# Out:
# anomaly
#  1    374460
# -1     19676
# Name: count, dtype: int64
#        Time           Source  No.      Destination    Length  \
# 0  0.000000    192.167.8.166    1  192.167.255.255  0.001006
# 1  0.000624    192.167.8.166    2  192.167.255.255  0.001006
# 2  0.000930  VMware_8a:5c:e6    3        Broadcast  0.000362
# 3  0.001725  VMware_8a:5c:e6    4        Broadcast  0.000362
# 4  0.002522  VMware_8a:5c:e6    5        Broadcast  0.000362
#
#    Protocol_BROWSER  Protocol_DHCP  Protocol_DNS  Protocol_HTTP  \
# 0             False          False         False          False
# 1             False          False         False          False
# 2             False          False         False          False
# 3             False          False         False          False
# 4             False          False         False          False
#
#    Protocol_ICMP  ...  Protocol_OCSP  Protocol_RARP  Protocol_SSLv2  \
# 0          False  ...          False          False           False
# 1          False  ...          False          False           False
# 2          False  ...          False          False           False
# 3          False  ...          False          False           False
# 4          False  ...          False          False           False
#
#    Protocol_STUN  Protocol_TCP  Protocol_TLSv1  Protocol_TLSv1.2  \
# 0          False         False           False             False
# 1          False         False           False             False
# 2          False         False           False             False
# 3          False         False           False             False
# 4          False         False           False             False
#
#    Protocol_TLSv1.3  is_query  anomaly
# 0             False         1       -1
# 1             False         1       -1
# 2             False         0       -1
# 3             False         0       -1
# 4             False         0       -1
#
# [5 rows x 22 columns]
